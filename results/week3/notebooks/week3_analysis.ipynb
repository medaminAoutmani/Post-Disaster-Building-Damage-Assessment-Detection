# %% [markdown]
# # Week 3 Baseline Analysis
#
# Use this notebook to inspect `metrics/training_log.csv`, training curves, prediction panels, and failure cases for the preserved Week 3 binary segmentation baseline.
